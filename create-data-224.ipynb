# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
cropped_dir = 'data-224/train_cropped'
compressed_dir_90 = 'data-224/train_compressed_90'
compressed_dir_70 = 'data-224/train_compressed_70'
output_dir_res_5 = 'data-224/train_resize_5'
output_dir_res_8 = 'data-224/train_resize_8'
output_dir_res_15 = 'data-224/train_resize_15'
output_dir_res_20 = 'data-224/train_resize_20'
output_dir_gamma_8 = 'data-224/train_gamma_8'
output_dir_gamma_12 = 'data-224/train_gamma_12'
train_dir = 'data/train'
valid_dir = 'data/validation'
test_img = 'Motorola-X/(MotoX)100.jpg'

# %%
# Execute if generating cropped directories
def generateDirs(source, target):
    if not os.path.exists(target):
        print('Creating parent dir ', target)
        os.makedirs(target)
    if len(os.listdir(target)) == 0:
        for cam in os.listdir(source):
            os.makedirs(os.path.join(target, cam))
        print('Generating dirs for ', target)

# %%
generateDirs(train_dir, cropped_dir)
generateDirs(train_dir, compressed_dir_90)
generateDirs(train_dir, compressed_dir_70)
generateDirs(train_dir, output_dir_res_5)
generateDirs(train_dir, output_dir_res_8)
generateDirs(train_dir, output_dir_res_15)
generateDirs(train_dir, output_dir_res_20)
generateDirs(train_dir, output_dir_gamma_8)
generateDirs(train_dir, output_dir_gamma_12)
generateDirs(train_dir, valid_dir)
# Out:
# Generating dirs for  data/validation

# %%
# Crop photos
crop_dimension = 224
file_format = '.tif'

# %%
def crop(img, crop_dim):
    edge = crop_dim // 2
    height, width, _ = img.shape
    center_height = height // 2
    center_width = width // 2
    top = center_height - edge
    bottom = center_height + edge
    left = center_width - edge
    right = center_width + edge
    return img[top:bottom,left:right]

# %%
samples_per_folder = 55
# Generate Validation Data
source_dirs = ['data/train_cropped'
               ,'data/train_compressed_90'
               ,'data/train_compressed_70'
               ,'data/train_resize_5'
               ,'data/train_resize_8'
               ,'data/train_resize_15'
               ,'data/train_resize_20'
               ,'data/train_gamma_8'
               ,'data/train_gamma_12']

file_number = 0
for source_dir in source_dirs:
    camera_dirs = os.listdir(source_dir)
    print('Moving into ' + source_dir)
    for camera_dir in camera_dirs:
        path = os.path.join(source_dir, camera_dir)
        filenames = os.listdir(path)
        np.random.shuffle(filenames)
        print('Working on ', path, 'with', len(filenames), 'files')
        # generate indices here
        for filename in filenames[:samples_per_folder]:
            file_number += 1
            img = cv2.imread(os.path.join(path, filename))
            cropped = crop(img, crop_dimension)
            if (cropped.shape[0] != crop_dimension or cropped.shape[1] != crop_dimension):
                print('Invalid shape for image at', os.path.join(path, filename), ". Not saving")
            else:
                cv2.imwrite(os.path.join(valid_dir, camera_dir, 'validation-' + str(file_number)  + file_format), cropped)
# Out:
# Moving into data/train_cropped
# Working on  data/train_cropped/iPhone-6 with  275  files
# Working on  data/train_cropped/Samsung-Galaxy-S4 with  275  files
# Working on  data/train_cropped/Motorola-Nexus-6 with  275  files
# Working on  data/train_cropped/HTC-1-M7 with  275  files
# Working on  data/train_cropped/Motorola-Droid-Maxx with  275  files
# Working on  data/train_cropped/Samsung-Galaxy-Note3 with  275  files
# Working on  data/train_cropped/Motorola-X with  275  files
# Working on  data/train_cropped/iPhone-4s with  275  files
# Working on  data/train_cropped/Sony-NEX-7 with  275  files
# Working on  data/train_cropped/LG-Nexus-5x with  275  files
# Moving into data/train_compressed_90
# Working on  data/train_compressed_90/LG-Nexus-5x with  275  files
# Working on  data/train_compressed_90/Motorola-Nexus-6 with  275  files
# Working on  data/train_compressed_90/iPhone-4s with  275  files
# Working on  data/train_compressed_90/Motorola-X with  275  files
# Working on  data/train_compressed_90/HTC-1-M7 with  275  files
# Working on  data/train_compressed_90/iPhone-6 with  275  files
# Working on  data/train_compressed_90/Sony-NEX-7 with  275  files
# Working on  data/train_compressed_90/Samsung-Galaxy-Note3 with  275  files
# Working on  data/train_compressed_90/Samsung-Galaxy-S4 with  275  files
# Working on  data/train_compressed_90/Motorola-Droid-Maxx with  275  files
# Moving into data/train_compressed_70
# Working on  data/train_compressed_70/Sony-NEX-7 with  275  files
# Working on  data/train_compressed_70/Motorola-X with  275  files
# Working on  data/train_compressed_70/Samsung-Galaxy-Note3 with  275  files
# Working on  data/train_compressed_70/Motorola-Nexus-6 with  275  files
# Working on  data/train_compressed_70/HTC-1-M7 with  275  files
# Working on  data/train_compressed_70/iPhone-4s with  275  files
# Working on  data/train_compressed_70/LG-Nexus-5x with  275  files
# Working on  data/train_compressed_70/iPhone-6 with  275  files
# Working on  data/train_compressed_70/Motorola-Droid-Maxx with  275  files
# Working on  data/train_compressed_70/Samsung-Galaxy-S4 with  275  files
# Moving into data/train_resize_5
# Working on  data/train_resize_5/Samsung-Galaxy-S4 with  275  files
# Working on  data/train_resize_5/Motorola-Nexus-6 with  275  files
# Working on  data/train_resize_5/Sony-NEX-7 with  275  files
# Working on  data/train_resize_5/iPhone-6 with  275  files
# Working on  data/train_resize_5/HTC-1-M7 with  275  files
# Working on  data/train_resize_5/Motorola-Droid-Maxx with  275  files
# Working on  data/train_resize_5/Samsung-Galaxy-Note3 with  275  files
# Working on  data/train_resize_5/Motorola-X with  275  files
# Working on  data/train_resize_5/LG-Nexus-5x with  275  files
# Working on  data/train_resize_5/iPhone-4s with  275  files
# Moving into data/train_resize_8
# Working on  data/train_resize_8/Motorola-X with  275  files
# Working on  data/train_resize_8/Samsung-Galaxy-S4 with  275  files
# Working on  data/train_resize_8/Sony-NEX-7 with  275  files
# Working on  data/train_resize_8/Motorola-Nexus-6 with  275  files
# Working on  data/train_resize_8/iPhone-4s with  275  files
# Working on  data/train_resize_8/iPhone-6 with  275  files
# Working on  data/train_resize_8/Motorola-Droid-Maxx with  275  files
# Working on  data/train_resize_8/LG-Nexus-5x with  275  files
# Working on  data/train_resize_8/Samsung-Galaxy-Note3 with  275  files
# Working on  data/train_resize_8/HTC-1-M7 with  275  files
# Moving into data/train_resize_15
# Working on  data/train_resize_15/Motorola-X with  275  files
# Working on  data/train_resize_15/LG-Nexus-5x with  275  files
# Working on  data/train_resize_15/Samsung-Galaxy-Note3 with  275  files
# Working on  data/train_resize_15/Sony-NEX-7 with  275  files
# Working on  data/train_resize_15/Motorola-Droid-Maxx with  275  files
# Working on  data/train_resize_15/iPhone-4s with  275  files
# Working on  data/train_resize_15/Motorola-Nexus-6 with  275  files
# Working on  data/train_resize_15/Samsung-Galaxy-S4 with  275  files
# Working on  data/train_resize_15/HTC-1-M7 with  275  files
# Working on  data/train_resize_15/iPhone-6 with  275  files
# Moving into data/train_resize_20
# Working on  data/train_resize_20/Motorola-Droid-Maxx with  275  files
# Working on  data/train_resize_20/Sony-NEX-7 with  275  files
# Working on  data/train_resize_20/Motorola-X with  275  files
# Working on  data/train_resize_20/LG-Nexus-5x with  275  files
# Working on  data/train_resize_20/iPhone-4s with  275  files
# Working on  data/train_resize_20/iPhone-6 with  275  files
# Working on  data/train_resize_20/Motorola-Nexus-6 with  275  files
# Working on  data/train_resize_20/Samsung-Galaxy-Note3 with  275  files
# Working on  data/train_resize_20/Samsung-Galaxy-S4 with  275  files
# Working on  data/train_resize_20/HTC-1-M7 with  275  files
# Moving into data/train_gamma_8
# Working on  data/train_gamma_8/iPhone-4s with  275  files
# Working on  data/train_gamma_8/Motorola-X with  275  files
# Working on  data/train_gamma_8/Samsung-Galaxy-S4 with  275  files
# Working on  data/train_gamma_8/LG-Nexus-5x with  275  files
# Working on  data/train_gamma_8/Sony-NEX-7 with  275  files
# Working on  data/train_gamma_8/HTC-1-M7 with  275  files
# Working on  data/train_gamma_8/Motorola-Droid-Maxx with  275  files
# Working on  data/train_gamma_8/Motorola-Nexus-6 with  275  files
# Working on  data/train_gamma_8/iPhone-6 with  275  files
# Working on  data/train_gamma_8/Samsung-Galaxy-Note3 with  275  files
# Moving into data/train_gamma_12
# Working on  data/train_gamma_12/Sony-NEX-7 with  275  files
# Working on  data/train_gamma_12/Motorola-Nexus-6 with  275  files
# Working on  data/train_gamma_12/iPhone-6 with  275  files
# Working on  data/train_gamma_12/Motorola-Droid-Maxx with  275  files
# Working on  data/train_gamma_12/Motorola-X with  275  files
# Working on  data/train_gamma_12/Samsung-Galaxy-Note3 with  275  files
# Working on  data/train_gamma_12/HTC-1-M7 with  275  files
# Working on  data/train_gamma_12/LG-Nexus-5x with  275  files
# Working on  data/train_gamma_12/iPhone-4s with  275  files
# Working on  data/train_gamma_12/Samsung-Galaxy-S4 with  275  files

# %%
# Generate cropped images
for source_dir in os.listdir(train_dir):
    path = os.path.join(train_dir, source_dir)
    print('Parsing files in ', path)
    for filename in os.listdir(path):
        
        img = cv2.imread(os.path.join(path, filename))
        cropped = crop(img, crop_dimension)
        cv2.imwrite(os.path.join(cropped_dir, source_dir, filename[:-4] + file_format), cropped)
# Out:
# Parsing files in  data/train/LG-Nexus-5x
# Parsing files in  data/train/Motorola-Droid-Maxx
# Parsing files in  data/train/iPhone-4s
# Parsing files in  data/train/iPhone-6
# Parsing files in  data/train/Sony-NEX-7
# Parsing files in  data/train/Motorola-Nexus-6
# Parsing files in  data/train/HTC-1-M7
# Parsing files in  data/train/Samsung-Galaxy-Note3
# Parsing files in  data/train/Motorola-X
# Parsing files in  data/train/Samsung-Galaxy-S4

# %%
output_dir_90 = 'data-224/train_compressed_90'
output_dir_70 = 'data-224/train_compressed_70'
output_dir_res_5 = 'data-224/train_resize_5'
output_dir_res_8 = 'data-224/train_resize_8'
output_dir_res_15 = 'data-224/train_resize_15'
output_dir_res_20 = 'data-224/train_resize_20'

# %%
# Generate cropped images with JPEG compression
for source_dir in os.listdir(cropped_dir):
    path = os.path.join(cropped_dir, source_dir)
    print('Parsing files in ', path)
    for filename in os.listdir(path):
        
        img = cv2.imread(os.path.join(path, filename))
        #cropped = crop(img, crop_dimension)
        # TODO: Fix compression
        cv2.imwrite(os.path.join(output_dir_90, source_dir, filename[:-4] + '.jpg'), img, [int(cv2.IMWRITE_JPEG_QUALITY), 90])
        cv2.imwrite(os.path.join(output_dir_70, source_dir, filename[:-4] + '.jpg'), img, [int(cv2.IMWRITE_JPEG_QUALITY), 70])
# Out:
# Parsing files in  data-224/train_cropped/Samsung-Galaxy-Note3
# Parsing files in  data-224/train_cropped/Samsung-Galaxy-S4
# Parsing files in  data-224/train_cropped/Motorola-X
# Parsing files in  data-224/train_cropped/Motorola-Nexus-6
# Parsing files in  data-224/train_cropped/Sony-NEX-7
# Parsing files in  data-224/train_cropped/Motorola-Droid-Maxx
# Parsing files in  data-224/train_cropped/LG-Nexus-5x
# Parsing files in  data-224/train_cropped/iPhone-4s
# Parsing files in  data-224/train_cropped/iPhone-6
# Parsing files in  data-224/train_cropped/HTC-1-M7

# %%
# Generate resized & cropped images with JPEG compression
for source_dir in os.listdir(train_dir):
    path = os.path.join(train_dir, source_dir)
    print('Parsing files in ', path)
    for filename in os.listdir(path):        
        img = cv2.imread(os.path.join(path, filename))

        res_5 = crop(cv2.resize(img, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_CUBIC), crop_dimension)
        res_8 = crop(cv2.resize(img, None, fx=0.8, fy=0.8, interpolation=cv2.INTER_CUBIC), crop_dimension)
        res_15 = crop(cv2.resize(img, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC), crop_dimension)
        res_20 = crop(cv2.resize(img, None, fx=2.0, fy=2.0, interpolation=cv2.INTER_CUBIC), crop_dimension)
        
        cv2.imwrite(os.path.join(output_dir_res_5, source_dir, filename[:-4] + file_format), res_5)
        cv2.imwrite(os.path.join(output_dir_res_8, source_dir, filename[:-4] + file_format), res_8)
        cv2.imwrite(os.path.join(output_dir_res_15, source_dir, filename[:-4] + file_format), res_15)
        cv2.imwrite(os.path.join(output_dir_res_20, source_dir, filename[:-4] + file_format), res_20)
# Out:
# Parsing files in  data/train/LG-Nexus-5x
# Parsing files in  data/train/Motorola-Droid-Maxx
# Parsing files in  data/train/iPhone-4s
# Parsing files in  data/train/iPhone-6
# Parsing files in  data/train/Sony-NEX-7
# Parsing files in  data/train/Motorola-Nexus-6
# Parsing files in  data/train/HTC-1-M7
# Parsing files in  data/train/Samsung-Galaxy-Note3
# Parsing files in  data/train/Motorola-X
# Parsing files in  data/train/Samsung-Galaxy-S4

# %%
def adjust_gamma(image, gamma=1.0):
    # build a lookup table mapping the pixel values [0, 255] to
    # their adjusted gamma values
    invGamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** invGamma) * 255
        for i in np.arange(0, 256)]).astype("uint8")
 
    # apply gamma correction using the lookup table
    return cv2.LUT(image, table)

# %%
# Adjust gamma
# from https://www.pyimagesearch.com/2015/10/05/opencv-gamma-correction/
gamma_table_8 = np.array([((i / 255.0) ** (1.0 / 0.8)) * 255 for i in np.arange(0, 256)]).astype("uint8")
gamma_table_12 = np.array([((i / 255.0) ** (1.0 / 1.2)) * 255 for i in np.arange(0, 256)]).astype("uint8")

# %%
# Generate cropped images with JPEG compression
for source_dir in os.listdir(cropped_dir):
    path = os.path.join(cropped_dir, source_dir)
    print('Parsing files in ', path)
    for filename in os.listdir(path):
        
        img = cv2.imread(os.path.join(path, filename))
        cv2.imwrite(os.path.join(output_dir_gamma_8, source_dir, filename[:-4] + file_format), cv2.LUT(img, gamma_table_8))
        cv2.imwrite(os.path.join(output_dir_gamma_12, source_dir, filename[:-4] + file_format), cv2.LUT(img, gamma_table_12))
# Out:
# Parsing files in  data-224/train_cropped/Samsung-Galaxy-Note3
# Parsing files in  data-224/train_cropped/Samsung-Galaxy-S4
# Parsing files in  data-224/train_cropped/Motorola-X
# Parsing files in  data-224/train_cropped/Motorola-Nexus-6
# Parsing files in  data-224/train_cropped/Sony-NEX-7
# Parsing files in  data-224/train_cropped/Motorola-Droid-Maxx
# Parsing files in  data-224/train_cropped/LG-Nexus-5x
# Parsing files in  data-224/train_cropped/iPhone-4s
# Parsing files in  data-224/train_cropped/iPhone-6
# Parsing files in  data-224/train_cropped/HTC-1-M7

# %%
img = cv2.imread(os.path.join(output_dir_gamma_8, test_img[:-4] + '.tif'))
plt.imshow(img)

# %%
img = cv2.imread(os.path.join(output_dir_gamma_12, test_img[:-4] + '.tif'))
plt.imshow(img)
